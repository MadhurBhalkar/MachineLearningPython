# %%
import pandas as pd
from sklearn.datasets import fetch_20newsgroups
import numpy as np
import matplotlib.pyplot as plt
import itertools
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import Normalizer
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier

# %%
C:\Users\Madhur Bhalkar\Desktop\

# %%
df=pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/Everything Privacy/twitter_data_processed.csv")

# %%
# read csv
from tqdm import tqdm
csv_data = pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/Everything Privacy/twitter_data_processed.csv")
csv_data.head(n=5)
text_content=[]
text_labels=[]
for index,row in tqdm(csv_data.iterrows(),total=csv_data.shape[0]):
    text_content.append(row['Content'])
    text_labels.append(row['Privacy'])
    
print('Completed')
print(len(text_content),len(text_labels))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 6023/6023 [00:00<00:00, 11226.04it/s]
# Completed
# 6023 6023

# %%
labels = csv_data['Privacy'].astype('category').cat.categories.tolist()
Label_mapping = {'Privacy' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}
#print(Label_mapping)

#Replacing the Strings with Numbers to feed as a input to our model
csv_data.replace(Label_mapping, inplace=True)

# %%
from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([
                         ('clf-svm', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, max_iter=5, random_state=42))])

text_clf_svm = text_clf_svm.fit(X_train, Y_train)
predicted_svm = text_clf_svm.predict(X_test)
np.mean(predicted_svm == Y_test)
# Out:
# c:\users\madhur bhalkar\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# 0.8273858921161825

# %%
#BAGGING
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier

text_clf = Pipeline([
                     ('clf', BaggingClassifier(KNeighborsClassifier()))
                     ])

text_clf.fit(X_train, Y_train)


predicted = text_clf.predict(X_test)

print(text_clf.score(X_test, Y_test))
# Out:
# 0.754356846473029

# %%
#BOOSTING
from sklearn.ensemble import GradientBoostingClassifier
text_clf1 = Pipeline([
                     ('clf', GradientBoostingClassifier(n_estimators=100,verbose=2)),
                     ])

text_clf1.fit(X_train, Y_train)


predicted = text_clf.predict(X_test)
print(text_clf1.score(X_test, Y_test))
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.9703            6.49s
#          2           0.9677            6.10s
#          3           0.9656            6.07s
#          4           0.9638            5.78s
#          5           0.9621            5.72s
#          6           0.9605            5.43s
#          7           0.9592            5.39s
#          8           0.9569            5.46s
#          9           0.9552            5.45s
#         10           0.9538            5.37s
#         11           0.9521            5.36s
#         12           0.9510            5.16s
#         13           0.9501            5.08s
#         14           0.9489            5.03s
#         15           0.9480            4.95s
#         16           0.9469            4.92s
#         17           0.9454            4.81s
#         18           0.9439            4.82s
#         19           0.9430            4.72s
#         20           0.9420            4.73s
# ...

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
text_clf3 = Pipeline([
                     ('clf', RandomForestClassifier(n_estimators=100)),
                     ])

text_clf3.fit(X_train, Y_train)


predicted = text_clf3.predict(X_test)
print(text_clf3.score(X_test, Y_test))
# Out:
# 0.8215767634854771

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

text_clf2 = Pipeline([
                     ('clf', MultinomialNB()),
                     ])

text_clf2.fit(X_train, Y_train)


predicted = text_clf2.predict(X_test)

print(metrics.classification_report(Y_test, predicted))

print(text_clf2.score(X_test, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.83      0.85      0.84      1002
#            2       0.14      0.12      0.13       203
#
#     accuracy                           0.73      1205
#    macro avg       0.48      0.49      0.48      1205
# weighted avg       0.71      0.73      0.72      1205
#
# 0.725311203319502

# %%
df10=pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/CREATED DATA/FINALTWEETS.csv")

# %%
df10
# Out:
#        Unnamed: 0      User_Name      Tweet_ID                Source  \
# 0               0     @BillGates  1.160000e+18              Sprinklr
# 1               1     @BillGates  1.160000e+18              Sprinklr
# 2               2     @BillGates  1.160000e+18              Sprinklr
# 3               3     @BillGates  1.160000e+18              Sprinklr
# 4               4     @BillGates  1.160000e+18              Sprinklr
# 5               5     @BillGates  1.160000e+18              Sprinklr
# 6               6     @BillGates  1.160000e+18              Sprinklr
# 7               7     @BillGates  1.160000e+18              Sprinklr
# 8               8     @BillGates  1.150000e+18              Sprinklr
# 9               9     @BillGates  1.150000e+18              Sprinklr
# 10             10     @BillGates  1.150000e+18              Sprinklr
# 11             11     @BillGates  1.150000e+18              Sprinklr
# 12             12     @BillGates  1.150000e+18  Twitter Media Studio
# ...

# %%
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 18267/18267 [00:01<00:00, 12817.26it/s]
# Completed
# 18267

# %%
csv_data.dropna()
# Out:
#        Unnamed: 0      User_Name      Tweet_ID                Source  \
# 0               0     @BillGates  1.160000e+18              Sprinklr
# 1               1     @BillGates  1.160000e+18              Sprinklr
# 2               2     @BillGates  1.160000e+18              Sprinklr
# 3               3     @BillGates  1.160000e+18              Sprinklr
# 4               4     @BillGates  1.160000e+18              Sprinklr
# 5               5     @BillGates  1.160000e+18              Sprinklr
# 6               6     @BillGates  1.160000e+18              Sprinklr
# 7               7     @BillGates  1.160000e+18              Sprinklr
# 8               8     @BillGates  1.150000e+18              Sprinklr
# 9               9     @BillGates  1.150000e+18              Sprinklr
# 10             10     @BillGates  1.150000e+18              Sprinklr
# 11             11     @BillGates  1.150000e+18              Sprinklr
# 12             12     @BillGates  1.150000e+18  Twitter Media Studio
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Construct a bag of words matrix.
# This will lowercase everything, and ignore all punctuation by default.
# It will also remove stop words.
vectorizer = CountVectorizer(lowercase=True, stop_words="english")

X1 = vectorizer.fit_transform(text_content1)

# %%
dfx=csv_data[csv_data["Content"].notnull()]

# %%
# read csv
from tqdm import tqdm
#csv_data = pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/CREATED DATA/FINALTWEETS.csv")
csv_data.head(n=5)
text_content1=[]
text_labels=[]
for index,row in tqdm(dfx.iterrows(),total=dfx.shape[0]):
    text_content1.append(row['Content'])
    #text_labels.append(row['Privacy'])
    
print('Completed')
print(len(text_content1))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 17115/17115 [00:01<00:00, 12683.21it/s]
# Completed
# 17115

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Construct a bag of words matrix.
# This will lowercase everything, and ignore all punctuation by default.
# It will also remove stop words.
vectorizer = CountVectorizer(lowercase=True, stop_words="english")

X1 = vectorizer.fit_transform(text_content1)

# %%
X1
# Out:
# <17115x32074 sparse matrix of type '<class 'numpy.int64'>'
# 	with 169417 stored elements in Compressed Sparse Row format>
